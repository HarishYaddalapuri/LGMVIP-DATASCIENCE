# %% [markdown]
# <a href="https://colab.research.google.com/github/HarishYaddalapuri/LGMVIP-DATASCIENCE/blob/main/Image_to_pencil_sketch_conversion_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMAGE TO PENCIL SKETCH WITH PYTHON

# %% [markdown]
# **Done by Harish Yadav**

# %% [markdown]
# import Libraries

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("/content/image005.jpg")

# %% [markdown]
# Display the Original Image

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=785x515 at 0x7F6F3F95A0D0>

# %% [markdown]
# Transforming the Image into a Pencil Sketch

# %% [markdown]
#  Convert OG Image to Gray-Scale Image

# %%
grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=785x515 at 0x7F6F3F8E69D0>

# %% [markdown]
# Invert the Gray-Scale Image

# %%
invert_img=cv2.bitwise_not(grey_img)
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=785x515 at 0x7F6F3F8DBD90>

# %% [markdown]
# Blur the Inverted Image

# %%
blur_img=cv2.GaussianBlur(invert_img, (111,111),0)
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=785x515 at 0x7F6F3F8E67D0>

# %% [markdown]
# Invert the Blurred Image

# %%
invblur_img=cv2.bitwise_not(blur_img)
cv2_imshow(invblur_img)
# Out:
# <PIL.Image.Image image mode=L size=785x515 at 0x7F6F3F8E69D0>

# %% [markdown]
# Pencil Sketch Image

# %%
sketch_img=cv2.divide(grey_img,invblur_img, scale=256.0)
cv2.imwrite('sketch.png', sketch_img)
cv2_imshow(sketch_img)
# Out:
# <PIL.Image.Image image mode=L size=785x515 at 0x7F6F3E077990>

# %% [markdown]
# Display the Original Image vs Pencil Sketch

# %%
plt.figure(figsize=(20,15))

plt.subplot(1,2,1)
plt.title('Original Image', size=19)
RGB_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.axis('off') 

plt.subplot(1,2,2)
plt.title('Pencil Sketch', size=19)
rgb_sketch=cv2.cvtColor(sketch_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.savefig('temp1.png')
plt.show()
